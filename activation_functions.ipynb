# %% [markdown]
# <a href="https://colab.research.google.com/github/Tiya4425/-datasciencecoursera/blob/main/activation_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![all.png](data:image/png;base64,...)

# %% [markdown]
# ![sigmoid.png](data:image/png;base64,...)

# %% [markdown]
# <h3 style='color:purple'>Sigmoid</h3>

# %%
import math

def sigmoid(x):
  return 1 / (1 + math.exp(-x))

# %%
sigmoid(100)
# Out:
# 1.0

# %%
sigmoid(1)
# Out:
# 0.7310585786300049

# %%
sigmoid(-56)
# Out:
# 4.780892883885469e-25

# %%
sigmoid(0.5)
# Out:
# 0.6224593312018546

# %% [markdown]
# ![tanh.png](data:image/png;base64,...)

# %% [markdown]
# <h3 style='color:purple'>tanh</h3>

# %%
def tanh(x):
  return (math.exp(x) - math.exp(-x)) / (math.exp(x) + math.exp(-x))

# %%
tanh(-56)
# Out:
# -1.0

# %%
tanh(50)
# Out:
# 1.0

# %%
tanh(1)
# Out:
# 0.7615941559557649

# %% [markdown]
# <h3 style='color:purple'>ReLU</h3>

# %% [markdown]
# ![relu.png](data:image/png;base64,...)

# %%
def relu(x):
    return max(0,x)

# %%
relu(-100)
# Out:
# 0

# %%
relu(8)
# Out:
# 8

# %% [markdown]
# ![leaky.png](data:image/png;base64,...)

# %% [markdown]
# <h3 style='color:purple'>Leaky ReLU</h3>

# %%
def leaky_relu(x):
    return max(0.1*x,x)

# %%
leaky_relu(-100)
# Out:
# -10.0

# %%
leaky_relu(8)
# Out:
# 8
